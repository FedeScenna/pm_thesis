# %%
import pandas as pd
import numpy as np

# %%
mapping = pd.read_excel("data/CandidateEmployeeID.xlsx")
mapping["Employee ID"] = mapping["Employee ID"].astype(str)
mapping.dtypes
# Out:
# c:\Users\feder\anaconda3\envs\pmthesis\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Employee ID     object
# Candidate ID    object
# dtype: object

# %%
df = pd.read_csv("data/AES - Candidate Journey by Stage 2026-07-23 20_00 GMT-3.csv", skiprows=6)
df.dtypes
print(df.shape)
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_13308\2280719598.py:1: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/AES - Candidate Journey by Stage 2026-07-23 20_00 GMT-3.csv", skiprows=6)
# (2713296, 24)

# %%
df = df.merge(mapping, how="left", on="Candidate ID")
df
# Out:
#                                                  Candidate  Current Worker ID  \
# 0        Rene Chicas Sandoval ‎- R1032853 Liniero De 1a...            1043733
# 1        Rene Chicas Sandoval ‎- R1032853 Liniero De 1a...            1043733
# 2        Rene Chicas Sandoval ‎- R1032853 Liniero De 1a...            1043733
# 3        Rene Chicas Sandoval ‎- R1032853 Liniero De 1a...            1043733
# 4        Rene Chicas Sandoval ‎- R1032853 Liniero De 1a...            1043733
# ...                                                    ...                ...
# 2713291  Ryan Robinson ‎- R1064016 Stockkeeper General ...            1043733
# 2713292  Jermaine Horne ‎- R1064016 Stockkeeper General...            1043733
# 2713293  Gerald Hysenaj ‎- R1063734 Associate Engineer,...            1043733
# 2713294    Hassan Javaid ‎- R1063904 M&A Analyst (C911618)            1043733
# 2713295  MILTON REYES ‎- R1064099 Ingeniero/a Senior Si...            1043733
#
# ...
